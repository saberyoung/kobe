# %% [markdown]
# # Some examples show how to use pst.Plotter

# %% [markdown]
# import module and initialize trigger, tilings, galaxy object

# %%
from pst.pipeline.PstParseTriggers import PstParseTriggers
from pst.pipeline.PstGetTilings import PstGetTilings
from pst.pipeline.PstGetGalaxies import PstGetGalaxies
from pst.view.PstPlotter import PstPlotter

# %matplotlib notebook

# trigger
_gw=PstParseTriggers()
_gw.url('https://gracedb.ligo.org/api/superevents/S190510g/files/bayestar.fits.gz')

# tiling
tel1=PstGetTilings()
tel1.generate(limra=[0,360],limdec=[-20,90],fovra=9.,fovdec=9.)
tel1.set_name('VST')

# galaxies
tel2=PstGetGalaxies()
tel2.generate(catalog='GLADE', limdist=[0,40])
tel2.set_name('PROMPT')

# plotter
_plotter=PstPlotter()
# Out:
# NSIDE = 512
# ORDERING = NESTED in fits file
# INDXSCHM = IMPLICIT
# Ordering converted to RING
# Ordering converted to RING
# Ordering converted to RING
# INFO:pst.pipeline.PstGetGalaxies:3778 galaxies selected from VII/281
# Ordering converted to RING

# %%
fig=_plotter.triggershow(_gw,contours=[.9], ptype='m', theta=90, phi=0, psi=0, nest=None, 
                     coord='C', norm='None', vmin=0,  vmax=10**(-5), 
                     fignum=1, cbar=True, title='S190510g sky localization')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
'''
fig=_plotter.locshow(_gw, psttilings=tel1, pstgalaxies=None,
                tellist=None, theta=90, phi=0, psi=0, figsize=(15,10),
                contours=[.9], nest=None, coord='C', norm='None', vmin=0,
                vmax=10**(-5), fignum=1, ptype='m', cbar=True, obstime=None,
                nside=None, title='sky localization')
'''
# Out:
# "\nfig=_plotter.locshow(_gw, psttilings=tel1, pstgalaxies=None,\n                tellist=None, theta=90, phi=0, psi=0, figsize=(15,10),\n                contours=[.9], nest=None, coord='C', norm='None', vmin=0,\n                vmax=10**(-5), fignum=1, ptype='m', cbar=True, obstime=None,\n                nside=None, title='sky localization')\n"

# %%
tel1.set_contour(_gw, cls=[.5])
# Out:
# INFO:pst.pipeline.PstParseTriggers:hpmap has already been parsed
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-4-d0119a293b57> in <module>
# ----> 1 tel1.set_contour(_gw, cls=[.5])
#
# /opt/miniconda3/envs/astroconda/lib/python3.6/site-packages/pstools-0.5.1.1-py3.6.egg/pst/pipeline/PstGetTilings.py in set_contour(self, triggerobj, cls, nest, frac)
#     836                 from pst.cookbook import is_seq
#     837                 if is_seq(cls):  cls = [cls[0]]
# --> 838                 _data = self.cut_contours(triggerobj, cls=cls, nest=nest, frac=frac)
#     839                 self.data = _data[cls[0]]
#     840
#
# /opt/miniconda3/envs/astroconda/lib/python3.6/site-packages/pstools-0.5.1.1-py3.6.egg/pst/pipeline/PstGetTilings.py in cut_contours(self, triggerobj, cls, nest, frac)
#     887                         idhpx = idlist[cc]
#     888                         idtiles = PstGetTilings.ipix_in_box(self.data['ra'], self.data['dec'],
# --> 889                                         self.data['fovra'],self.data['fovdec'],nside,nest)
#     890                         ele = self.common_ele(idtiles, idhpx)
#     891                         nn = 0
#
# /opt/miniconda3/envs/astroconda/lib/python3.6/site-packages/pstools-0.5.1.1-py3.6.egg/pst/pipeline/PstGetTilings.py in ipix_in_box(ra, dec, width, height, nside, nest)
#    1584                         ipix_fov_box = []
#    1585                         for _xyz in xyz:
# -> 1586                                 ipix_fov_box.append(hp.query_polygon(nside, _xyz, nest=nest))
#    1587                 else:
#    1588                         ipix_fov_box = hp.query_polygon(nside, xyz, nest=nest)
#
# healpy/src/_query_disc.pyx in healpy._query_disc.query_polygon()
#
# RuntimeError: Unknown exception

# %%
fig=_plotter.tilingshow(tel1,theta=90, phi=0, psi=0, nest=None, coord=None, fignum=1)

# %%
len(tel1.data['ra'])
# Out:
# 94
